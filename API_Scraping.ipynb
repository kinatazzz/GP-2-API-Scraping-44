# %% [markdown]
# # **GP 2 - SCRAPING & API**

# %% [markdown]
# *Логирование:*

# %%
import logging
from logging.handlers import RotatingFileHandler

logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)
logger.propagate = False

if logger.hasHandlers():
    logger.handlers.clear()

formatter = logging.Formatter('%(asctime)s [%(levelname)s] [%(name)s:%(lineno)d] - %(message)s')

file_handler = RotatingFileHandler('parser.log', maxBytes=5_000_000, backupCount=3)
file_handler.setLevel(logging.INFO)
file_handler.setFormatter(formatter)

console_handler = logging.StreamHandler()
console_handler.setLevel(logging.DEBUG)
console_handler.setFormatter(formatter)

logger.addHandler(file_handler)
logger.addHandler(console_handler)
# Out:
# 2025-03-04 16:49:09,601 [DEBUG] [__main__:28] - Это сообщение DEBUG: должно выводиться только один раз.
# 2025-03-04 16:49:09,602 [INFO] [__main__:29] - Это сообщение INFO: тоже один раз, и в файл, и в консоль.

# %% [markdown]
# ## API AVIASALES

# %% [markdown]
# *В качестве 1 из источника данных используем Aviasales - будем собирать данные путем сбора через API.*

# %%
import requests
import pandas as pd
import time

logger.info("Получение данных от Aviasales, OpenWeatherMap ")

aviasales_api_key = '8a56da7bfb183a0451edc4fcc4234223'
origin_list = ['MOW', 'LED', 'AER', 'OVB', 'SVX', 'KZN', 'MRV', 'KGD', 'UFA', 'KJA', 'IKT', 'KUF', 'VVO']  # топ городов с аэропортами в России

final_offers = []

# "горящие" направления из Aviasales
logger.info("Получение 'горящих' направлений из Aviasales.")
for origin_key in origin_list:
    logger.debug(f"Отправляем запрос к API Aviasales для {origin_key}.")
    try:
        response = requests.get(
            f"https://api.travelpayouts.com/aviasales/v3/get_special_offers?origin={origin_key}&locale=en&token={aviasales_api_key}"
        )
        response.raise_for_status()  # выбросит исключение при плохом ответе
        response_data = response.json()

        if response_data.get('success') and 'data' in response_data:
            offers = response_data['data']
            logger.debug(f"Для {origin_key} получено предложений: {len(offers)}")

            for offer in offers:
                final_offers.append({
                    'Airline': offer.get('airline'),
                    'Airline Title': offer.get('airline_title'),
                    'Departure': offer.get('departure_at'),
                    'Destination': offer.get('destination'),
                    'Destination Name': offer.get('destination_name'),
                    'Duration': offer.get('duration'),
                    'Flight Number': offer.get('flight_number'),
                    'Price': offer.get('price'),
                    'Origin': offer.get('origin'),
                    'Origin Name': offer.get('origin_name'),
                    'Title': offer.get('title')
                })
        else:
            logger.warning(f"Нет данных для {origin_key}.")
    except requests.exceptions.RequestException as e:
        logger.exception(f"Ошибка при запросе к Aviasales для {origin_key}: {e}")

    # чтобы не перегружать API
    time.sleep(1)


df = pd.DataFrame(final_offers)
logger.info(f"Создан DataFrame df для горящих направлений размером {df.shape} .")
# Out:
# 2025-03-04 16:49:27,496 [INFO] [__main__:5] - Получение данных от Aviasales, OpenWeatherMap
# 2025-03-04 16:49:27,498 [INFO] [__main__:13] - Получение 'горящих' направлений из Aviasales.
# 2025-03-04 16:49:27,501 [DEBUG] [__main__:15] - Отправляем запрос к API Aviasales для MOW.
# 2025-03-04 16:49:27,848 [DEBUG] [__main__:25] - Для MOW получено предложений: 9
# 2025-03-04 16:49:28,849 [DEBUG] [__main__:15] - Отправляем запрос к API Aviasales для LED.
# 2025-03-04 16:49:29,089 [DEBUG] [__main__:25] - Для LED получено предложений: 9
# 2025-03-04 16:49:30,090 [DEBUG] [__main__:15] - Отправляем запрос к API Aviasales для AER.
# 2025-03-04 16:49:30,371 [DEBUG] [__main__:25] - Для AER получено предложений: 9
# 2025-03-04 16:49:31,372 [DEBUG] [__main__:15] - Отправляем запрос к API Aviasales для OVB.
# 2025-03-04 16:49:31,509 [DEBUG] [__main__:25] - Для OVB получено предложений: 9
# 2025-03-04 16:49:32,510 [DEBUG] [__main__:15] - Отправляем запрос к API Aviasales для SVX.
# 2025-03-04 16:49:32,811 [DEBUG] [__main__:25] - Для SVX получено предложений: 9
# 2025-03-04 16:49:33,812 [DEBUG] [__main__:15] - Отправляем запрос к API Aviasales для KZN.
# 2025-03-04 16:49:33,947 [DEBUG] [__main__:25] - Для KZN получено предложений: 9
# 2025-03-04 16:49:34,948 [DEBUG] [__main__:15] - Отправляем запрос к API Aviasales для MRV.
# 2025-03-04 16:49:35,074 [DEBUG] [__main__:25] - Для MRV получено предложений: 9
# 2025-03-04 16:49:36,075 [DEBUG] [__main__:15] - Отправляем запрос к API Aviasales для KGD.
# 2025-03-04 16:49:36,200 [DEBUG] [__main__:25] - Для KGD получено предложений: 9
# 2025-03-04 16:49:37,201 [DEBUG] [__main__:15] - Отправляем запрос к API Aviasales для UFA.
# 2025-03-04 16:49:37,468 [DEBUG] [__main__:25] - Для UFA получено предложений: 9
# 2025-03-04 16:49:38,469 [DEBUG] [__main__:15] - Отправляем запрос к API Aviasales для KJA.
# 2025-03-04 16:49:38,739 [DEBUG] [__main__:25] - Для KJA получено предложений: 9
# 2025-03-04 16:49:39,740 [DEBUG] [__main__:15] - Отправляем запрос к API Aviasales для IKT.
# 2025-03-04 16:49:39,852 [DEBUG] [__main__:25] - Для IKT получено предложений: 9
# 2025-03-04 16:49:40,853 [DEBUG] [__main__:15] - Отправляем запрос к API Aviasales для KUF.
# 2025-03-04 16:49:40,984 [DEBUG] [__main__:25] - Для KUF получено предложений: 9
# 2025-03-04 16:49:41,986 [DEBUG] [__main__:15] - Отправляем запрос к API Aviasales для VVO.
# 2025-03-04 16:49:42,141 [DEBUG] [__main__:25] - Для VVO получено предложений: 9
# 2025-03-04 16:49:43,145 [INFO] [__main__:51] - Создан DataFrame df для горящих направлений размером (117, 11) .

# %%
df
# Out:
#     Airline           Airline Title                  Departure Destination  \
# 0        DP                  Pobeda  2025-03-15T09:30:00+03:00         ERF
# 1        DP                  Pobeda  2025-03-06T08:30:00+03:00         GLA
# 2        DP                  Pobeda  2025-03-08T08:30:00+03:00         CMF
# 3        TK        Turkish Airlines  2025-03-28T07:50:00+03:00         YMQ
# 4        MU  China Eastern Airlines  2025-03-10T21:05:00+03:00         NSN
# ..      ...                     ...                        ...         ...
# 112      MU  China Eastern Airlines  2025-03-14T19:05:00+10:00         KMG
# 113      CA               Air China  2025-04-03T18:10:00+10:00         SGN
# 114      IO                  IrAero  2025-04-08T07:45:00+10:00         NHA
# 115      CA               Air China  2025-04-03T18:10:00+10:00         BJS
# 116      HO        Juneyao Airlines  2025-04-17T04:00:00+10:00         DPS
#
#      Destination Name  Duration Flight Number  Price Origin  Origin Name  \
# 0              Erfurt      1680           839  28136    MOW       Moscow
# 1             Glasgow       795           839  13892    MOW       Moscow
# 2            Chambery      2085           839  33596    MOW       Moscow
# 3            Montreal      1105           737  46216    MOW       Moscow
# 4              Nelson      2950           204  91087    MOW       Moscow
# ..                ...       ...           ...    ...    ...          ...
# 112           Kunming       475          8299  10854    VVO  Vladivostok
# 113  Ho Chi Minh City       570           812  20112    VVO  Vladivostok
# 114         Nha Trang       890          6404  47932    VVO  Vladivostok
# 115           Beijing       160           812   4582    VVO  Vladivostok
# 116   Denpasar (Bali)       830          6245  39034    VVO  Vladivostok
#
#                                                  Title
# 0                   Flight deals from Moscow to Erfurt
# 1                  Flight deals from Moscow to Glasgow
# 2                 Flight deals from Moscow to Chambery
# 3                 Flight deals from Moscow to Montreal
# 4                   Flight deals from Moscow to Nelson
# ..                                                 ...
# 112           Flight deals from Vladivostok to Kunming
# 113  Flight deals from Vladivostok to Ho Chi Minh City
# 114         Flight deals from Vladivostok to Nha Trang
# 115           Flight deals from Vladivostok to Beijing
# 116   Flight deals from Vladivostok to Denpasar (Bali)
#
# [117 rows x 11 columns]

# %%
# по каждому направлению билеты
logger.info("Получение деталей билетов по каждому направлению.")

all_results = []

pairs = df[['Origin', 'Destination']].drop_duplicates()
logger.debug(f"Уникальных пар Origin-Destination: {pairs.shape[0]}")

for index, row in pairs.iterrows():
    origin = row['Origin']
    destination = row['Destination']

    url = 'https://api.travelpayouts.com/aviasales/v3/prices_for_dates'
    params = {
        'origin': origin,
        'destination': destination,
        'limit': 1000,
        'token': aviasales_api_key
    }

    logger.debug(f"Запрос к API  для пары {origin}-{destination}")
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        json_response = response.json()

        if 'data' in json_response and json_response['data']:
            flights = json_response['data']
            logger.debug(f"Для пары {origin}-{destination} получено билетов: {len(flights)}")

            for flight in flights:
                all_results.append({
                    'origin': flight.get('origin'),
                    'destination': flight.get('destination'),
                    'price': flight.get('price'),
                    'airline': flight.get('airline'),
                    'flight_number': flight.get('flight_number'),
                    'departure_at': flight.get('departure_at'),
                    'transfers': flight.get('transfers'),
                    'duration': flight.get('duration'),
                    'link': flight.get('link')
                })
        else:
            logger.warning(f'Нет данных  для направления {origin} → {destination}')
    except requests.exceptions.RequestException as e:
        logger.exception(f'Ошибка при запросе к Aviasales для {origin} → {destination}: {e}')


    time.sleep(1.5)

df_flights = pd.DataFrame(all_results)
logger.info(f"Создан DataFrame df_flights размера {df_flights.shape} (детали билетов).")
# Out:
# 2025-03-04 16:49:57,791 [INFO] [__main__:2] - Получение деталей билетов по каждому направлению.
# 2025-03-04 16:49:57,797 [DEBUG] [__main__:7] - Уникальных пар Origin-Destination: 117
# 2025-03-04 16:49:57,799 [DEBUG] [__main__:21] - Запрос к API  для пары MOW-ERF
# 2025-03-04 16:49:58,065 [DEBUG] [__main__:29] - Для пары MOW-ERF получено билетов: 14
# 2025-03-04 16:49:59,566 [DEBUG] [__main__:21] - Запрос к API  для пары MOW-GLA
# 2025-03-04 16:49:59,867 [DEBUG] [__main__:29] - Для пары MOW-GLA получено билетов: 35
# 2025-03-04 16:50:01,368 [DEBUG] [__main__:21] - Запрос к API  для пары MOW-CMF
# 2025-03-04 16:50:01,771 [DEBUG] [__main__:29] - Для пары MOW-CMF получено билетов: 7
# 2025-03-04 16:50:03,273 [DEBUG] [__main__:21] - Запрос к API  для пары MOW-YMQ
# 2025-03-04 16:50:03,484 [DEBUG] [__main__:29] - Для пары MOW-YMQ получено билетов: 120
# 2025-03-04 16:50:04,986 [DEBUG] [__main__:21] - Запрос к API  для пары MOW-NSN
# 2025-03-04 16:50:05,250 [DEBUG] [__main__:29] - Для пары MOW-NSN получено билетов: 1
# 2025-03-04 16:50:06,751 [DEBUG] [__main__:21] - Запрос к API  для пары MOW-DJE
# 2025-03-04 16:50:06,861 [DEBUG] [__main__:29] - Для пары MOW-DJE получено билетов: 51
# 2025-03-04 16:50:08,362 [DEBUG] [__main__:21] - Запрос к API  для пары MOW-BNE
# 2025-03-04 16:50:08,561 [DEBUG] [__main__:29] - Для пары MOW-BNE получено билетов: 101
# 2025-03-04 16:50:10,062 [DEBUG] [__main__:21] - Запрос к API  для пары MOW-TLN
# 2025-03-04 16:50:10,179 [DEBUG] [__main__:29] - Для пары MOW-TLN получено билетов: 5
# 2025-03-04 16:50:11,680 [DEBUG] [__main__:21] - Запрос к API  для пары MOW-TNA
# 2025-03-04 16:50:11,804 [DEBUG] [__main__:29] - Для пары MOW-TNA получено билетов: 41
# 2025-03-04 16:50:13,305 [DEBUG] [__main__:21] - Запрос к API  для пары LED-ERF
# 2025-03-04 16:50:13,412 [DEBUG] [__main__:29] - Для пары LED-ERF получено билетов: 3
# 2025-03-04 16:50:14,913 [DEBUG] [__main__:21] - Запрос к API  для пары LED-BDA
# 2025-03-04 16:50:15,233 [DEBUG] [__main__:29] - Для пары LED-BDA получено билетов: 3
# 2025-03-04 16:50:16,734 [DEBUG] [__main__:21] - Запрос к API  для пары LED-KHI
# 2025-03-04 16:50:16,962 [DEBUG] [__main__:29] - Для пары LED-KHI получено билетов: 235
# 2025-03-04 16:50:18,464 [DEBUG] [__main__:21] - Запрос к API  для пары LED-NYT
# 2025-03-04 16:50:18,577 [DEBUG] [__main__:29] - Для пары LED-NYT получено билетов: 2
# 2025-03-04 16:50:20,079 [DEBUG] [__main__:21] - Запрос к API  для пары LED-LCA
# 2025-03-04 16:50:20,306 [DEBUG] [__main__:29] - Для пары LED-LCA получено билетов: 204
# 2025-03-04 16:50:21,808 [DEBUG] [__main__:21] - Запрос к API  для пары LED-MCT
# 2025-03-04 16:50:21,996 [DEBUG] [__main__:29] - Для пары LED-MCT получено билетов: 93
# 2025-03-04 16:50:23,498 [DEBUG] [__main__:21] - Запрос к API  для пары LED-SYD
# 2025-03-04 16:50:23,690 [DEBUG] [__main__:29] - Для пары LED-SYD получено билетов: 113
# 2025-03-04 16:50:25,192 [DEBUG] [__main__:21] - Запрос к API  для пары LED-PSA
# 2025-03-04 16:50:25,311 [DEBUG] [__main__:29] - Для пары LED-PSA получено билетов: 18
# 2025-03-04 16:50:26,813 [DEBUG] [__main__:21] - Запрос к API  для пары LED-TIA
# 2025-03-04 16:50:27,031 [DEBUG] [__main__:29] - Для пары LED-TIA получено билетов: 132
# 2025-03-04 16:50:28,533 [DEBUG] [__main__:21] - Запрос к API  для пары AER-KUL
# 2025-03-04 16:50:28,667 [DEBUG] [__main__:29] - Для пары AER-KUL получено билетов: 73
# 2025-03-04 16:50:30,168 [DEBUG] [__main__:21] - Запрос к API  для пары AER-BJV
# 2025-03-04 16:50:30,708 [DEBUG] [__main__:29] - Для пары AER-BJV получено билетов: 117
# 2025-03-04 16:50:32,209 [DEBUG] [__main__:21] - Запрос к API  для пары AER-GZP
# 2025-03-04 16:50:32,502 [DEBUG] [__main__:29] - Для пары AER-GZP получено билетов: 122
# 2025-03-04 16:50:34,004 [DEBUG] [__main__:21] - Запрос к API  для пары AER-MIL
# 2025-03-04 16:50:34,384 [DEBUG] [__main__:29] - Для пары AER-MIL получено билетов: 171
# 2025-03-04 16:50:35,886 [DEBUG] [__main__:21] - Запрос к API  для пары AER-VCE
# 2025-03-04 16:50:36,182 [DEBUG] [__main__:29] - Для пары AER-VCE получено билетов: 118
# 2025-03-04 16:50:37,684 [DEBUG] [__main__:21] - Запрос к API  для пары AER-WAW
# 2025-03-04 16:50:37,831 [DEBUG] [__main__:29] - Для пары AER-WAW получено билетов: 72
# 2025-03-04 16:50:39,333 [DEBUG] [__main__:21] - Запрос к API  для пары AER-TMJ
# 2025-03-04 16:50:39,542 [DEBUG] [__main__:29] - Для пары AER-TMJ получено билетов: 24
# 2025-03-04 16:50:41,043 [DEBUG] [__main__:21] - Запрос к API  для пары AER-JED
# 2025-03-04 16:50:41,166 [DEBUG] [__main__:29] - Для пары AER-JED получено билетов: 36
# 2025-03-04 16:50:42,667 [DEBUG] [__main__:21] - Запрос к API  для пары AER-LPA
# 2025-03-04 16:50:42,789 [DEBUG] [__main__:29] - Для пары AER-LPA получено билетов: 13
# 2025-03-04 16:50:44,291 [DEBUG] [__main__:21] - Запрос к API  для пары OVB-UTP
# 2025-03-04 16:50:44,509 [DEBUG] [__main__:29] - Для пары OVB-UTP получено билетов: 200
# 2025-03-04 16:50:46,010 [DEBUG] [__main__:21] - Запрос к API  для пары OVB-SYD
# 2025-03-04 16:50:46,141 [DEBUG] [__main__:29] - Для пары OVB-SYD получено билетов: 46
# 2025-03-04 16:50:47,642 [DEBUG] [__main__:21] - Запрос к API  для пары OVB-MNL
# 2025-03-04 16:50:47,803 [DEBUG] [__main__:29] - Для пары OVB-MNL получено билетов: 48
# 2025-03-04 16:50:49,305 [DEBUG] [__main__:21] - Запрос к API  для пары OVB-KQT
# 2025-03-04 16:50:49,411 [DEBUG] [__main__:29] - Для пары OVB-KQT получено билетов: 15
# 2025-03-04 16:50:50,913 [DEBUG] [__main__:21] - Запрос к API  для пары OVB-BOD
# 2025-03-04 16:50:51,042 [DEBUG] [__main__:29] - Для пары OVB-BOD получено билетов: 13
# 2025-03-04 16:50:52,544 [DEBUG] [__main__:21] - Запрос к API  для пары OVB-SHA
# 2025-03-04 16:50:52,752 [DEBUG] [__main__:29] - Для пары OVB-SHA получено билетов: 168
# 2025-03-04 16:50:54,254 [DEBUG] [__main__:21] - Запрос к API  для пары OVB-CMB
# 2025-03-04 16:50:54,471 [DEBUG] [__main__:29] - Для пары OVB-CMB получено билетов: 116
# 2025-03-04 16:50:55,974 [DEBUG] [__main__:21] - Запрос к API  для пары OVB-DYU
# 2025-03-04 16:50:56,183 [DEBUG] [__main__:29] - Для пары OVB-DYU получено билетов: 159
# 2025-03-04 16:50:57,685 [DEBUG] [__main__:21] - Запрос к API  для пары OVB-PWQ
# 2025-03-04 16:50:57,936 [DEBUG] [__main__:29] - Для пары OVB-PWQ получено билетов: 11
# 2025-03-04 16:50:59,437 [DEBUG] [__main__:21] - Запрос к API  для пары SVX-ROM
# 2025-03-04 16:50:59,708 [DEBUG] [__main__:29] - Для пары SVX-ROM получено билетов: 194
# 2025-03-04 16:51:01,209 [DEBUG] [__main__:21] - Запрос к API  для пары SVX-BAH
# 2025-03-04 16:51:01,350 [DEBUG] [__main__:29] - Для пары SVX-BAH получено билетов: 23
# 2025-03-04 16:51:02,852 [DEBUG] [__main__:21] - Запрос к API  для пары SVX-TYO
# 2025-03-04 16:51:03,073 [DEBUG] [__main__:29] - Для пары SVX-TYO получено билетов: 170
# 2025-03-04 16:51:04,575 [DEBUG] [__main__:21] - Запрос к API  для пары SVX-BUD
# 2025-03-04 16:51:04,852 [DEBUG] [__main__:29] - Для пары SVX-BUD получено билетов: 100
# 2025-03-04 16:51:06,353 [DEBUG] [__main__:21] - Запрос к API  для пары SVX-VIE
# 2025-03-04 16:51:06,627 [DEBUG] [__main__:29] - Для пары SVX-VIE получено билетов: 67
# 2025-03-04 16:51:08,128 [DEBUG] [__main__:21] - Запрос к API  для пары SVX-GOI
# 2025-03-04 16:51:08,344 [DEBUG] [__main__:29] - Для пары SVX-GOI получено билетов: 221
# 2025-03-04 16:51:09,846 [DEBUG] [__main__:21] - Запрос к API  для пары SVX-BOM
# 2025-03-04 16:51:10,111 [DEBUG] [__main__:29] - Для пары SVX-BOM получено билетов: 36
# 2025-03-04 16:51:11,613 [DEBUG] [__main__:21] - Запрос к API  для пары SVX-NMA
# 2025-03-04 16:51:11,795 [DEBUG] [__main__:29] - Для пары SVX-NMA получено билетов: 116
# 2025-03-04 16:51:13,297 [DEBUG] [__main__:21] - Запрос к API  для пары SVX-PWQ
# 2025-03-04 16:51:13,435 [DEBUG] [__main__:29] - Для пары SVX-PWQ получено билетов: 8
# 2025-03-04 16:51:14,936 [DEBUG] [__main__:21] - Запрос к API  для пары KZN-BAK
# 2025-03-04 16:51:15,333 [DEBUG] [__main__:29] - Для пары KZN-BAK получено билетов: 209
# 2025-03-04 16:51:16,836 [DEBUG] [__main__:21] - Запрос к API  для пары KZN-KMG
# 2025-03-04 16:51:16,950 [DEBUG] [__main__:29] - Для пары KZN-KMG получено билетов: 5
# 2025-03-04 16:51:18,451 [DEBUG] [__main__:21] - Запрос к API  для пары KZN-PSA
# 2025-03-04 16:51:18,699 [DEBUG] [__main__:29] - Для пары KZN-PSA получено билетов: 5
# 2025-03-04 16:51:20,200 [DEBUG] [__main__:21] - Запрос к API  для пары KZN-DYU
# 2025-03-04 16:51:20,410 [DEBUG] [__main__:29] - Для пары KZN-DYU получено билетов: 143
# 2025-03-04 16:51:21,912 [DEBUG] [__main__:21] - Запрос к API  для пары KZN-NAV
# 2025-03-04 16:51:22,021 [DEBUG] [__main__:29] - Для пары KZN-NAV получено билетов: 12
# 2025-03-04 16:51:23,523 [DEBUG] [__main__:21] - Запрос к API  для пары KZN-LBD
# 2025-03-04 16:51:23,703 [DEBUG] [__main__:29] - Для пары KZN-LBD получено билетов: 119
# 2025-03-04 16:51:25,205 [DEBUG] [__main__:21] - Запрос к API  для пары KZN-NHA
# 2025-03-04 16:51:25,411 [DEBUG] [__main__:29] - Для пары KZN-NHA получено билетов: 134
# 2025-03-04 16:51:26,916 [DEBUG] [__main__:21] - Запрос к API  для пары KZN-JED
# 2025-03-04 16:51:27,092 [DEBUG] [__main__:29] - Для пары KZN-JED получено билетов: 77
# 2025-03-04 16:51:28,599 [DEBUG] [__main__:21] - Запрос к API  для пары KZN-DXB
# 2025-03-04 16:51:28,968 [DEBUG] [__main__:29] - Для пары KZN-DXB получено билетов: 219
# 2025-03-04 16:51:30,470 [DEBUG] [__main__:21] - Запрос к API  для пары MRV-BUD
# 2025-03-04 16:51:30,602 [DEBUG] [__main__:29] - Для пары MRV-BUD получено билетов: 65
# 2025-03-04 16:51:32,104 [DEBUG] [__main__:21] - Запрос к API  для пары MRV-GZT
# 2025-03-04 16:51:32,209 [DEBUG] [__main__:29] - Для пары MRV-GZT получено билетов: 3
# 2025-03-04 16:51:33,710 [DEBUG] [__main__:21] - Запрос к API  для пары MRV-TAS
# 2025-03-04 16:51:33,991 [DEBUG] [__main__:29] - Для пары MRV-TAS получено билетов: 211
# 2025-03-04 16:51:35,501 [DEBUG] [__main__:21] - Запрос к API  для пары MRV-AYT
# 2025-03-04 16:51:35,703 [DEBUG] [__main__:29] - Для пары MRV-AYT получено билетов: 236
# 2025-03-04 16:51:37,214 [DEBUG] [__main__:21] - Запрос к API  для пары MRV-HRI
# 2025-03-04 16:51:37,329 [DEBUG] [__main__:29] - Для пары MRV-HRI получено билетов: 13
# 2025-03-04 16:51:38,831 [DEBUG] [__main__:21] - Запрос к API  для пары MRV-KUL
# 2025-03-04 16:51:38,975 [DEBUG] [__main__:29] - Для пары MRV-KUL получено билетов: 28
# 2025-03-04 16:51:40,479 [DEBUG] [__main__:21] - Запрос к API  для пары MRV-BJV
# 2025-03-04 16:51:40,612 [DEBUG] [__main__:29] - Для пары MRV-BJV получено билетов: 76
# 2025-03-04 16:51:42,113 [DEBUG] [__main__:21] - Запрос к API  для пары MRV-ALA
# 2025-03-04 16:51:42,309 [DEBUG] [__main__:29] - Для пары MRV-ALA получено билетов: 180
# 2025-03-04 16:51:43,811 [DEBUG] [__main__:21] - Запрос к API  для пары MRV-LCA
# 2025-03-04 16:51:44,104 [DEBUG] [__main__:29] - Для пары MRV-LCA получено билетов: 113
# 2025-03-04 16:51:45,606 [DEBUG] [__main__:21] - Запрос к API  для пары KGD-NMA
# 2025-03-04 16:51:45,739 [DEBUG] [__main__:29] - Для пары KGD-NMA получено билетов: 81
# 2025-03-04 16:51:47,240 [DEBUG] [__main__:21] - Запрос к API  для пары KGD-OSS
# 2025-03-04 16:51:47,366 [DEBUG] [__main__:29] - Для пары KGD-OSS получено билетов: 71
# 2025-03-04 16:51:48,867 [DEBUG] [__main__:21] - Запрос к API  для пары KGD-FEG
# 2025-03-04 16:51:48,988 [DEBUG] [__main__:29] - Для пары KGD-FEG получено билетов: 56
# 2025-03-04 16:51:50,489 [DEBUG] [__main__:21] - Запрос к API  для пары KGD-ALA
# 2025-03-04 16:51:50,690 [DEBUG] [__main__:29] - Для пары KGD-ALA получено билетов: 143
# 2025-03-04 16:51:52,192 [DEBUG] [__main__:21] - Запрос к API  для пары KGD-LBD
# 2025-03-04 16:51:52,471 [DEBUG] [__main__:29] - Для пары KGD-LBD получено билетов: 40
# 2025-03-04 16:51:53,972 [DEBUG] [__main__:21] - Запрос к API  для пары KGD-REK
# 2025-03-04 16:51:54,082 [DEBUG] [__main__:29] - Для пары KGD-REK получено билетов: 3
# 2025-03-04 16:51:55,584 [DEBUG] [__main__:21] - Запрос к API  для пары KGD-DXB
# 2025-03-04 16:51:55,724 [DEBUG] [__main__:29] - Для пары KGD-DXB получено билетов: 66
# 2025-03-04 16:51:57,226 [DEBUG] [__main__:21] - Запрос к API  для пары KGD-VCE
# 2025-03-04 16:51:57,504 [DEBUG] [__main__:29] - Для пары KGD-VCE получено билетов: 8
# 2025-03-04 16:51:59,006 [DEBUG] [__main__:21] - Запрос к API  для пары KGD-TAS
# 2025-03-04 16:51:59,198 [DEBUG] [__main__:29] - Для пары KGD-TAS получено билетов: 149
# 2025-03-04 16:52:00,700 [DEBUG] [__main__:21] - Запрос к API  для пары UFA-LOS
# 2025-03-04 16:52:00,805 [DEBUG] [__main__:29] - Для пары UFA-LOS получено билетов: 1
# 2025-03-04 16:52:02,307 [DEBUG] [__main__:21] - Запрос к API  для пары UFA-SZX
# 2025-03-04 16:52:02,579 [DEBUG] [__main__:29] - Для пары UFA-SZX получено билетов: 20
# 2025-03-04 16:52:04,082 [DEBUG] [__main__:21] - Запрос к API  для пары UFA-AUH
# 2025-03-04 16:52:04,497 [DEBUG] [__main__:29] - Для пары UFA-AUH получено билетов: 71
# 2025-03-04 16:52:05,998 [DEBUG] [__main__:21] - Запрос к API  для пары UFA-LON
# 2025-03-04 16:52:06,135 [DEBUG] [__main__:29] - Для пары UFA-LON получено билетов: 57
# 2025-03-04 16:52:07,637 [DEBUG] [__main__:21] - Запрос к API  для пары UFA-HRG
# 2025-03-04 16:52:07,824 [DEBUG] [__main__:29] - Для пары UFA-HRG получено билетов: 97
# 2025-03-04 16:52:09,326 [DEBUG] [__main__:21] - Запрос к API  для пары UFA-PAR
# 2025-03-04 16:52:09,530 [DEBUG] [__main__:29] - Для пары UFA-PAR получено билетов: 127
# 2025-03-04 16:52:11,031 [DEBUG] [__main__:21] - Запрос к API  для пары UFA-RGN
# 2025-03-04 16:52:11,164 [DEBUG] [__main__:29] - Для пары UFA-RGN получено билетов: 11
# 2025-03-04 16:52:12,665 [DEBUG] [__main__:21] - Запрос к API  для пары UFA-BEG
# 2025-03-04 16:52:12,810 [DEBUG] [__main__:29] - Для пары UFA-BEG получено билетов: 83
# 2025-03-04 16:52:14,311 [DEBUG] [__main__:21] - Запрос к API  для пары UFA-TAS
# 2025-03-04 16:52:14,531 [DEBUG] [__main__:29] - Для пары UFA-TAS получено билетов: 238
# 2025-03-04 16:52:16,033 [DEBUG] [__main__:21] - Запрос к API  для пары KJA-BKK
# 2025-03-04 16:52:16,251 [DEBUG] [__main__:29] - Для пары KJA-BKK получено билетов: 265
# 2025-03-04 16:52:17,752 [DEBUG] [__main__:21] - Запрос к API  для пары KJA-UTP
# 2025-03-04 16:52:17,877 [DEBUG] [__main__:29] - Для пары KJA-UTP получено билетов: 121
# 2025-03-04 16:52:19,378 [DEBUG] [__main__:21] - Запрос к API  для пары KJA-KBV
# 2025-03-04 16:52:19,484 [DEBUG] [__main__:29] - Для пары KJA-KBV получено билетов: 9
# 2025-03-04 16:52:20,988 [DEBUG] [__main__:21] - Запрос к API  для пары KJA-TCI
# 2025-03-04 16:52:21,097 [DEBUG] [__main__:29] - Для пары KJA-TCI получено билетов: 8
# 2025-03-04 16:52:22,599 [DEBUG] [__main__:21] - Запрос к API  для пары KJA-TJU
# 2025-03-04 16:52:22,712 [DEBUG] [__main__:29] - Для пары KJA-TJU получено билетов: 9
# 2025-03-04 16:52:24,213 [DEBUG] [__main__:21] - Запрос к API  для пары KJA-NHA
# 2025-03-04 16:52:24,419 [DEBUG] [__main__:29] - Для пары KJA-NHA получено билетов: 169
# 2025-03-04 16:52:25,920 [DEBUG] [__main__:21] - Запрос к API  для пары KJA-HKT
# 2025-03-04 16:52:26,164 [DEBUG] [__main__:29] - Для пары KJA-HKT получено билетов: 229
# 2025-03-04 16:52:27,666 [DEBUG] [__main__:21] - Запрос к API  для пары KJA-GOI
# 2025-03-04 16:52:27,930 [DEBUG] [__main__:29] - Для пары KJA-GOI получено билетов: 38
# 2025-03-04 16:52:29,432 [DEBUG] [__main__:21] - Запрос к API  для пары KJA-MBJ
# 2025-03-04 16:52:29,538 [DEBUG] [__main__:29] - Для пары KJA-MBJ получено билетов: 2
# 2025-03-04 16:52:31,039 [DEBUG] [__main__:21] - Запрос к API  для пары IKT-UTP
# 2025-03-04 16:52:31,389 [DEBUG] [__main__:29] - Для пары IKT-UTP получено билетов: 162
# 2025-03-04 16:52:32,891 [DEBUG] [__main__:21] - Запрос к API  для пары IKT-SKD
# 2025-03-04 16:52:33,120 [DEBUG] [__main__:29] - Для пары IKT-SKD получено билетов: 91
# 2025-03-04 16:52:34,621 [DEBUG] [__main__:21] - Запрос к API  для пары IKT-CAN
# 2025-03-04 16:52:34,986 [DEBUG] [__main__:29] - Для пары IKT-CAN получено билетов: 96
# 2025-03-04 16:52:36,488 [DEBUG] [__main__:21] - Запрос к API  для пары IKT-SAI
# 2025-03-04 16:52:36,596 [DEBUG] [__main__:29] - Для пары IKT-SAI получено билетов: 5
# 2025-03-04 16:52:38,097 [DEBUG] [__main__:21] - Запрос к API  для пары IKT-BKK
# 2025-03-04 16:52:38,341 [DEBUG] [__main__:29] - Для пары IKT-BKK получено билетов: 306
# 2025-03-04 16:52:39,843 [DEBUG] [__main__:21] - Запрос к API  для пары IKT-TYO
# 2025-03-04 16:52:40,176 [DEBUG] [__main__:29] - Для пары IKT-TYO получено билетов: 128
# 2025-03-04 16:52:41,678 [DEBUG] [__main__:21] - Запрос к API  для пары IKT-TAS
# 2025-03-04 16:52:41,906 [DEBUG] [__main__:29] - Для пары IKT-TAS получено билетов: 210
# 2025-03-04 16:52:43,408 [DEBUG] [__main__:21] - Запрос к API  для пары IKT-HAN
# 2025-03-04 16:52:43,612 [DEBUG] [__main__:29] - Для пары IKT-HAN получено билетов: 189
# 2025-03-04 16:52:45,114 [DEBUG] [__main__:21] - Запрос к API  для пары IKT-RGN
# 2025-03-04 16:52:45,244 [DEBUG] [__main__:29] - Для пары IKT-RGN получено билетов: 16
# 2025-03-04 16:52:46,746 [DEBUG] [__main__:21] - Запрос к API  для пары KUF-LON
# 2025-03-04 16:52:47,017 [DEBUG] [__main__:29] - Для пары KUF-LON получено билетов: 58
# 2025-03-04 16:52:48,519 [DEBUG] [__main__:21] - Запрос к API  для пары KUF-NQZ
# 2025-03-04 16:52:48,816 [DEBUG] [__main__:29] - Для пары KUF-NQZ получено билетов: 81
# 2025-03-04 16:52:50,318 [DEBUG] [__main__:21] - Запрос к API  для пары KUF-EVN
# 2025-03-04 16:52:50,531 [DEBUG] [__main__:29] - Для пары KUF-EVN получено билетов: 231
# 2025-03-04 16:52:52,033 [DEBUG] [__main__:21] - Запрос к API  для пары KUF-TMJ
# 2025-03-04 16:52:52,146 [DEBUG] [__main__:29] - Для пары KUF-TMJ получено билетов: 12
# 2025-03-04 16:52:53,647 [DEBUG] [__main__:21] - Запрос к API  для пары KUF-TBS
# 2025-03-04 16:52:54,122 [DEBUG] [__main__:29] - Для пары KUF-TBS получено билетов: 205
# 2025-03-04 16:52:55,624 [DEBUG] [__main__:21] - Запрос к API  для пары KUF-BEG
# 2025-03-04 16:52:55,927 [DEBUG] [__main__:29] - Для пары KUF-BEG получено билетов: 103
# 2025-03-04 16:52:57,428 [DEBUG] [__main__:21] - Запрос к API  для пары KUF-ALA
# 2025-03-04 16:52:57,628 [DEBUG] [__main__:29] - Для пары KUF-ALA получено билетов: 146
# 2025-03-04 16:52:59,130 [DEBUG] [__main__:21] - Запрос к API  для пары KUF-TAS
# 2025-03-04 16:52:59,506 [DEBUG] [__main__:29] - Для пары KUF-TAS получено билетов: 197
# 2025-03-04 16:53:01,008 [DEBUG] [__main__:21] - Запрос к API  для пары KUF-JED
# 2025-03-04 16:53:01,138 [DEBUG] [__main__:29] - Для пары KUF-JED получено билетов: 27
# 2025-03-04 16:53:02,640 [DEBUG] [__main__:21] - Запрос к API  для пары VVO-ANC
# 2025-03-04 16:53:02,740 [DEBUG] [__main__:29] - Для пары VVO-ANC получено билетов: 6
# 2025-03-04 16:53:04,241 [DEBUG] [__main__:21] - Запрос к API  для пары VVO-BKK
# 2025-03-04 16:53:04,687 [DEBUG] [__main__:29] - Для пары VVO-BKK получено билетов: 265
# 2025-03-04 16:53:06,189 [DEBUG] [__main__:21] - Запрос к API  для пары VVO-CAN
# 2025-03-04 16:53:06,300 [DEBUG] [__main__:29] - Для пары VVO-CAN получено билетов: 91
# 2025-03-04 16:53:07,802 [DEBUG] [__main__:21] - Запрос к API  для пары VVO-UTP
# 2025-03-04 16:53:07,932 [DEBUG] [__main__:29] - Для пары VVO-UTP получено билетов: 83
# 2025-03-04 16:53:09,434 [DEBUG] [__main__:21] - Запрос к API  для пары VVO-KMG
# 2025-03-04 16:53:09,548 [DEBUG] [__main__:29] - Для пары VVO-KMG получено билетов: 5
# 2025-03-04 16:53:11,049 [DEBUG] [__main__:21] - Запрос к API  для пары VVO-SGN
# 2025-03-04 16:53:11,258 [DEBUG] [__main__:29] - Для пары VVO-SGN получено билетов: 104
# 2025-03-04 16:53:12,760 [DEBUG] [__main__:21] - Запрос к API  для пары VVO-NHA
# 2025-03-04 16:53:13,008 [DEBUG] [__main__:29] - Для пары VVO-NHA получено билетов: 188
# 2025-03-04 16:53:14,511 [DEBUG] [__main__:21] - Запрос к API  для пары VVO-BJS
# 2025-03-04 16:53:14,752 [DEBUG] [__main__:29] - Для пары VVO-BJS получено билетов: 260
# 2025-03-04 16:53:16,264 [DEBUG] [__main__:21] - Запрос к API  для пары VVO-DPS
# 2025-03-04 16:53:16,513 [DEBUG] [__main__:29] - Для пары VVO-DPS получено билетов: 128
# 2025-03-04 16:53:18,042 [INFO] [__main__:52] - Создан DataFrame df_flights размера (11048, 9) (детали билетов).

# %% [markdown]
# ## API OpenWeather

# %% [markdown]
# В качестве 1 из источника данных используем OpenWeather - будем собирать данные путем сбора через API.

# %%
#собираем погоду с OpenWeatherMap
logger.info("Запрос данных о погоде через OpenWeatherMap")
openweather_api_key = '15c5ac1c39b750c1e4770d7ab6970cea'
geocode_url = 'http://api.openweathermap.org/geo/1.0/direct'
weather_url = 'https://api.openweathermap.org/data/2.5/weather'

destination_to_weather = {}
unique_destinations = df['Destination Name'].unique()
logger.debug(f"Уникальных Destination Name: {len(unique_destinations)}")

for destination_name in unique_destinations:
    params = {
        'q': destination_name.split()[0],
        'limit': 1,
        'appid': openweather_api_key
    }
    try:
        openweather_response = requests.get(geocode_url, params=params)
        openweather_response.raise_for_status()
        geocode_data = openweather_response.json()

        if len(geocode_data) > 0:
            lat = geocode_data[0].get('lat')
            lon = geocode_data[0].get('lon')
            logger.debug(f"Координаты для {destination_name}: lat={lat}, lon={lon}")

            weather_params = {
                'lat': lat,
                'lon': lon,
                'appid': openweather_api_key,
                'units': 'metric'
            }
            weather_response = requests.get(weather_url, params=weather_params)
            weather_response.raise_for_status()
            weather_data = weather_response.json()

            main_weather = weather_data['weather'][0]['main']
            temperature = weather_data['main']['temp']
            destination_to_weather[destination_name] = {
                'Weather': main_weather,
                'Temperature': temperature
            }
        else:
            logger.warning(f"Не удалось найти координаты для '{destination_name}'")

    except requests.exceptions.RequestException as e:
        logger.exception(f"Ошибка при получении данных о погоде для {destination_name}: {e}")
    except KeyError as e:
        logger.error(f"Некорректная структура ответа OpenWeatherMap для {destination_name}: {e}")

# добавляем данные о погоде в DataFrame
df['Weather'] = df['Destination Name'].map(
    lambda name: destination_to_weather[name]['Weather'] if name in destination_to_weather else None
)
df['Temperature'] = df['Destination Name'].map(
    lambda name: destination_to_weather[name]['Temperature'] if name in destination_to_weather else None
)
logger.info("Информация о погоде добавлена в DataFrame -  df.")
# Out:
# 2025-03-04 16:54:31,055 [INFO] [__main__:2] - Запрос данных о погоде через OpenWeatherMap
# 2025-03-04 16:54:31,058 [DEBUG] [__main__:9] - Уникальных Destination Name: 81
# 2025-03-04 16:54:31,230 [DEBUG] [__main__:25] - Координаты для Erfurt: lat=50.9777974, lon=11.0287364
# 2025-03-04 16:54:31,464 [DEBUG] [__main__:25] - Координаты для Glasgow: lat=55.8609825, lon=-4.2488787
# 2025-03-04 16:54:31,676 [DEBUG] [__main__:25] - Координаты для Chambery: lat=45.5662672, lon=5.9203636
# 2025-03-04 16:54:31,886 [DEBUG] [__main__:25] - Координаты для Montreal: lat=45.5031824, lon=-73.5698065
# 2025-03-04 16:54:32,094 [DEBUG] [__main__:25] - Координаты для Nelson: lat=-41.2710849, lon=173.2836756
# 2025-03-04 16:54:32,296 [DEBUG] [__main__:25] - Координаты для Djerba: lat=33.77339055, lon=10.885904100766005
# 2025-03-04 16:54:32,508 [DEBUG] [__main__:25] - Координаты для Brisbane: lat=-27.4689682, lon=153.0234991
# 2025-03-04 16:54:32,709 [DEBUG] [__main__:25] - Координаты для Toulon: lat=43.1257311, lon=5.9304919
# 2025-03-04 16:54:32,913 [DEBUG] [__main__:25] - Координаты для Jinan: lat=36.6507007, lon=117.1140042
# 2025-03-04 16:54:33,115 [DEBUG] [__main__:25] - Координаты для Bermuda: lat=32.3018217, lon=-64.7603583
# 2025-03-04 16:54:33,323 [DEBUG] [__main__:25] - Координаты для Karachi: lat=24.8546842, lon=67.0207055
# 2025-03-04 16:54:33,525 [DEBUG] [__main__:25] - Координаты для Naypyidaw: lat=19.7540045, lon=96.1344976
# 2025-03-04 16:54:33,732 [DEBUG] [__main__:25] - Координаты для Larnaca: lat=34.9236095, lon=33.6236184
# 2025-03-04 16:54:33,936 [DEBUG] [__main__:25] - Координаты для Muscat: lat=23.61515, lon=58.5912467
# 2025-03-04 16:54:34,146 [DEBUG] [__main__:25] - Координаты для Sydney: lat=-33.8698439, lon=151.2082848
# 2025-03-04 16:54:34,351 [DEBUG] [__main__:25] - Координаты для Pisa: lat=43.7159395, lon=10.4018624
# 2025-03-04 16:54:34,566 [DEBUG] [__main__:25] - Координаты для Tirana: lat=41.3305141, lon=19.825562857582966
# 2025-03-04 16:54:34,777 [DEBUG] [__main__:25] - Координаты для Kuala Lumpur: lat=5.233493599999999, lon=96.7202306315261
# 2025-03-04 16:54:34,990 [DEBUG] [__main__:25] - Координаты для Bodrum: lat=37.0343987, lon=27.430651
# 2025-03-04 16:54:35,198 [DEBUG] [__main__:25] - Координаты для Gazipasa: lat=39.1201558, lon=27.176764
# 2025-03-04 16:54:35,403 [DEBUG] [__main__:25] - Координаты для Milan: lat=45.4641943, lon=9.1896346
# 2025-03-04 16:54:35,608 [DEBUG] [__main__:25] - Координаты для Venice: lat=45.4371908, lon=12.3345898
# 2025-03-04 16:54:35,873 [DEBUG] [__main__:25] - Координаты для Warsaw: lat=52.2319581, lon=21.0067249
# 2025-03-04 16:54:36,072 [DEBUG] [__main__:25] - Координаты для Termez: lat=37.2442466, lon=67.283151
# 2025-03-04 16:54:36,281 [DEBUG] [__main__:25] - Координаты для Jeddah: lat=21.5810088, lon=39.1653612
# 2025-03-04 16:54:36,484 [DEBUG] [__main__:25] - Координаты для Las Palmas: lat=43.4697786, lon=0.3098676
# 2025-03-04 16:54:36,693 [WARNING] [__main__:44] - Не удалось найти координаты для 'Utapao'
# 2025-03-04 16:54:36,862 [DEBUG] [__main__:25] - Координаты для Manila: lat=14.5948914, lon=120.9782618
# 2025-03-04 16:54:37,063 [WARNING] [__main__:44] - Не удалось найти координаты для 'Kurgon-Tyube (Bokhtar)'
# 2025-03-04 16:54:37,231 [DEBUG] [__main__:25] - Координаты для Bordeaux: lat=44.841225, lon=-0.5800364
# 2025-03-04 16:54:37,430 [DEBUG] [__main__:25] - Координаты для Shanghai: lat=31.2322758, lon=121.4692071
# 2025-03-04 16:54:37,640 [DEBUG] [__main__:25] - Координаты для Colombo: lat=6.9387469, lon=79.8541134
# 2025-03-04 16:54:37,855 [DEBUG] [__main__:25] - Координаты для Dushanbe: lat=38.5425835, lon=68.81521423589763
# 2025-03-04 16:54:38,066 [DEBUG] [__main__:25] - Координаты для Pavlodar: lat=52.2857573, lon=76.9455035
# 2025-03-04 16:54:38,275 [DEBUG] [__main__:25] - Координаты для Rome: lat=41.8933203, lon=12.4829321
# 2025-03-04 16:54:38,475 [DEBUG] [__main__:25] - Координаты для Bahrain: lat=26.0280409, lon=50.55316820508136
# 2025-03-04 16:54:38,674 [DEBUG] [__main__:25] - Координаты для Tokyo: lat=35.6828387, lon=139.7594549
# 2025-03-04 16:54:38,725 [DEBUG] [__main__:25] - Координаты для Budapest: lat=47.4979937, lon=19.0403594
# 2025-03-04 16:54:38,930 [DEBUG] [__main__:25] - Координаты для Vienna: lat=48.2083537, lon=16.3725042
# 2025-03-04 16:54:39,132 [DEBUG] [__main__:25] - Координаты для Goa: lat=13.6973443, lon=123.4885073
# 2025-03-04 16:54:39,336 [DEBUG] [__main__:25] - Координаты для Mumbai: lat=19.0785451, lon=72.878176
# 2025-03-04 16:54:39,540 [DEBUG] [__main__:25] - Координаты для Namangan: lat=40.9996482, lon=71.6726238
# 2025-03-04 16:54:39,751 [DEBUG] [__main__:25] - Координаты для Baku: lat=40.3755885, lon=49.8328009
# 2025-03-04 16:54:39,952 [DEBUG] [__main__:25] - Координаты для Kunming: lat=24.8843019, lon=102.8324209
# 2025-03-04 16:54:40,156 [DEBUG] [__main__:25] - Координаты для Nevsehir: lat=38.6250389, lon=34.7150685
# 2025-03-04 16:54:40,370 [DEBUG] [__main__:25] - Координаты для Khujand: lat=40.289306, lon=69.6232171
# 2025-03-04 16:54:40,581 [DEBUG] [__main__:25] - Координаты для Nha Trang: lat=27.9163455, lon=86.7164284
# 2025-03-04 16:54:40,804 [DEBUG] [__main__:25] - Координаты для Dubai: lat=25.2653471, lon=55.2924914
# 2025-03-04 16:54:41,009 [DEBUG] [__main__:25] - Координаты для Gaziantep: lat=37.0628317, lon=37.3792617
# 2025-03-04 16:54:41,216 [DEBUG] [__main__:25] - Координаты для Tashkent: lat=41.3123363, lon=69.2787079
# 2025-03-04 16:54:41,416 [DEBUG] [__main__:25] - Координаты для Antalya: lat=36.8872942, lon=30.7074549
# 2025-03-04 16:54:41,619 [DEBUG] [__main__:25] - Координаты для Hambantota: lat=6.1249126, lon=81.1242563
# 2025-03-04 16:54:41,830 [DEBUG] [__main__:25] - Координаты для Almaty: lat=43.2363924, lon=76.9457275
# 2025-03-04 16:54:42,042 [DEBUG] [__main__:25] - Координаты для Osh: lat=40.5361899, lon=72.8033618
# 2025-03-04 16:54:42,250 [DEBUG] [__main__:25] - Координаты для Fergana: lat=40.3764879, lon=71.7913193
# 2025-03-04 16:54:42,464 [DEBUG] [__main__:25] - Координаты для Reykjavik: lat=64.145981, lon=-21.9422367
# 2025-03-04 16:54:42,669 [DEBUG] [__main__:25] - Координаты для Lagos: lat=6.4550575, lon=3.3941795
# 2025-03-04 16:54:42,874 [DEBUG] [__main__:25] - Координаты для Shenzhen: lat=22.5445741, lon=114.0545429
# 2025-03-04 16:54:43,076 [DEBUG] [__main__:25] - Координаты для Abu Dhabi: lat=35.4044647, lon=134.7674637
# 2025-03-04 16:54:43,283 [DEBUG] [__main__:25] - Координаты для London: lat=51.5073219, lon=-0.1276474
# 2025-03-04 16:54:43,483 [DEBUG] [__main__:25] - Координаты для Hurghada: lat=27.222556, lon=33.8307062
# 2025-03-04 16:54:43,690 [DEBUG] [__main__:25] - Координаты для Paris: lat=48.8588897, lon=2.3200410217200766
# 2025-03-04 16:54:43,892 [DEBUG] [__main__:25] - Координаты для Yangon: lat=16.7967129, lon=96.1609916
# 2025-03-04 16:54:44,099 [DEBUG] [__main__:25] - Координаты для Belgrade: lat=44.8178131, lon=20.4568974
# 2025-03-04 16:54:44,305 [DEBUG] [__main__:25] - Координаты для Bangkok: lat=13.7524938, lon=100.4935089
# 2025-03-04 16:54:44,512 [DEBUG] [__main__:25] - Координаты для Krabi: lat=8.0634637, lon=98.9162345
# 2025-03-04 16:54:44,724 [DEBUG] [__main__:25] - Координаты для Tenerife: lat=28.2935785, lon=-16.621447121144122
# 2025-03-04 16:54:44,936 [WARNING] [__main__:44] - Не удалось найти координаты для 'Kulyab'
# 2025-03-04 16:54:45,103 [DEBUG] [__main__:25] - Координаты для Phuket: lat=7.8847901, lon=98.3891503
# 2025-03-04 16:54:45,310 [DEBUG] [__main__:25] - Координаты для Montego Bay: lat=33.5523384, lon=-117.1114905
# 2025-03-04 16:54:45,516 [DEBUG] [__main__:25] - Координаты для Samarkand: lat=39.6550017, lon=66.9756954
# 2025-03-04 16:54:45,721 [DEBUG] [__main__:25] - Координаты для Guangzhou: lat=23.1301964, lon=113.2592945
# 2025-03-04 16:54:45,928 [DEBUG] [__main__:25] - Координаты для Siem Reap: lat=5.5135979, lon=95.5233868
# 2025-03-04 16:54:46,144 [DEBUG] [__main__:25] - Координаты для Hanoi: lat=21.0294498, lon=105.8544441
# 2025-03-04 16:54:46,347 [DEBUG] [__main__:25] - Координаты для Astana: lat=51.1282205, lon=71.4306682
# 2025-03-04 16:54:46,413 [DEBUG] [__main__:25] - Координаты для Yerevan: lat=40.1776245, lon=44.5126174
# 2025-03-04 16:54:46,625 [DEBUG] [__main__:25] - Координаты для Tbilisi: lat=41.6934591, lon=44.8014495
# 2025-03-04 16:54:46,831 [DEBUG] [__main__:25] - Координаты для Anchorage: lat=61.2163129, lon=-149.894852
# 2025-03-04 16:54:47,030 [DEBUG] [__main__:25] - Координаты для Ho Chi Minh City: lat=36.5719389, lon=111.7309206
# 2025-03-04 16:54:47,244 [DEBUG] [__main__:25] - Координаты для Beijing: lat=39.906217, lon=116.3912757
# 2025-03-04 16:54:47,449 [DEBUG] [__main__:25] - Координаты для Denpasar (Bali): lat=-8.6524973, lon=115.2191175
# 2025-03-04 16:54:47,490 [INFO] [__main__:58] - Информация о погоде добавлена в DataFrame -  df.

# %% [markdown]
# ## Парсинг WikiVoyage (selenium + bs4)

# %% [markdown]
# *В качестве 1 из источника данных используем WikiVoyage - будем собирать данные путем сбора через Selenium и BeautifulSoup.*

# %% [markdown]
# Разбираемся с установкой одинаковых версий chrome driver и сhrome, для того чтобы selenium заработал.

# %%
# !apt-get update
# !apt-get install -y wget gnupg

# скачиваем для линукса (колаб использует линукс) гугл, скачиваем для селениума
# !wget -q -O - https://dl.google.com/linux/linux_signing_key.pub | apt-key add -
# !echo "deb [arch=amd64] http://dl.google.com/linux/chrome/deb/ stable main" >> /etc/apt/sources.list.d/google-chrome.list
# !apt-get update
# !apt-get install -y google-chrome-stable
# !pip install selenium webdriver-manager
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 6,555 B in 1s (5,087 B/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# gnupg is already the newest version (2.2.27-3ubuntu2.1).
# gnupg set to manually installed.
# wget is already the newest version (1.21.2-2ubuntu1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 50 not upgraded.
# Warning: apt-key is deprecated. Manage keyring files in trusted.gpg.d instead (see apt-key(8)).
# OK
# Get:1 http://dl.google.com/linux/chrome/deb stable InRelease [1,825 B]
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:4 http://dl.google.com/linux/chrome/deb stable/main amd64 Packages [1,211 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 3,036 B in 1s (2,112 B/s)
# Reading package lists... Done
# W: http://dl.google.com/linux/chrome/deb/dists/stable/InRelease: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libvulkan1 mesa-vulkan-drivers
# The following NEW packages will be installed:
#   google-chrome-stable libvulkan1 mesa-vulkan-drivers
# 0 upgraded, 3 newly installed, 0 to remove and 50 not upgraded.
# Need to get 125 MB of archives.
# After this operation, 423 MB of additional disk space will be used.
# Get:1 http://dl.google.com/linux/chrome/deb stable/main amd64 google-chrome-stable amd64 133.0.6943.141-1 [114 MB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvulkan1 amd64 1.3.204.1-2 [128 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 mesa-vulkan-drivers amd64 23.2.1-1ubuntu3.1~22.04.3 [10.7 MB]
# Fetched 125 MB in 2s (62.7 MB/s)
# Selecting previously unselected package libvulkan1:amd64.
# (Reading database ... 125412 files and directories currently installed.)
# Preparing to unpack .../libvulkan1_1.3.204.1-2_amd64.deb ...
# Unpacking libvulkan1:amd64 (1.3.204.1-2) ...
# Selecting previously unselected package google-chrome-stable.
# Preparing to unpack .../google-chrome-stable_133.0.6943.141-1_amd64.deb ...
# Unpacking google-chrome-stable (133.0.6943.141-1) ...
# Selecting previously unselected package mesa-vulkan-drivers:amd64.
# Preparing to unpack .../mesa-vulkan-drivers_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking mesa-vulkan-drivers:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up libvulkan1:amd64 (1.3.204.1-2) ...
# Setting up mesa-vulkan-drivers:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up google-chrome-stable (133.0.6943.141-1) ...
# update-alternatives: using /usr/bin/google-chrome-stable to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/google-chrome-stable to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# update-alternatives: using /usr/bin/google-chrome-stable to provide /usr/bin/google-chrome (google-chrome) in auto mode
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# Requirement already satisfied: selenium in /usr/local/lib/python3.11/dist-packages (4.29.0)
# Requirement already satisfied: webdriver-manager in /usr/local/lib/python3.11/dist-packages (4.0.2)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (2.3.0)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.11/dist-packages (from selenium) (0.29.0)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.11/dist-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.11/dist-packages (from selenium) (2025.1.31)
# Requirement already satisfied: typing_extensions~=4.9 in /usr/local/lib/python3.11/dist-packages (from selenium) (4.12.2)
# Requirement already satisfied: websocket-client~=1.8 in /usr/local/lib/python3.11/dist-packages (from selenium) (1.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from webdriver-manager) (2.32.3)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (from webdriver-manager) (1.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from webdriver-manager) (24.2)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium) (25.1.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium) (3.10)
# Requirement already satisfied: outcome in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.11/dist-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->webdriver-manager) (3.4.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %% [markdown]
# Непосредственно сам парсинг:

# %%
#Парсинг Wikivoyage
logger.info("Парсинг страниц Wikivoyage ( с помощью selenium).")

import time
from webdriver_manager.chrome import ChromeDriverManager
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from bs4 import BeautifulSoup

options = webdriver.ChromeOptions()
options.add_argument("--headless")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")

def parse_destination(destination_name):
    # парсим страницы Wikivoyage для конкретного destination_name, где возвращаем списки типов мест и наименований
    logger.debug(f"Для {destination_name}.")
    url = f'https://en.wikivoyage.org/wiki/{destination_name}#See'
    try:
        driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
        driver.get(url)
        time.sleep(5)
        html = driver.page_source
        driver.quit()

        soup = BeautifulSoup(html, 'html.parser')
        titles = [link['title'] for link in soup.find_all('a') if link.has_attr('title')]

        place_types = []
        places = []
        recording = False

        start_marker = 'Edit section: See'
        end_marker = 'Edit section: Do'

        for title in titles:
            if title == start_marker:
                recording = True
            elif title == end_marker:
                break
            elif recording:
                if 'Edit section: ' in title:
                    place_types.append(title.replace('Edit section: ', ''))
                else:
                    places.append(title)

        logger.debug(f"Найдено {len(place_types)} типов мест и {len(places)} мест для {destination_name}.")
        return place_types, places

    except Exception as e:
        logger.exception(f"Ошибка при парсинге  для {destination_name}: {e}")
        return [], []

if 'Place Types' not in df.columns:
    df['Place Types'] = pd.Series([], dtype='object')
if 'Places' not in df.columns:
    df['Places'] = pd.Series([], dtype='object')

for index, row in df.iterrows():
    destination_name = row['Destination Name']
    place_types, places = parse_destination(destination_name)
    df.at[index, 'Place Types'] = [place.split(' (')[0] for place in place_types]
    df.at[index, 'Places'] = [place.split(' (')[0] for place in places]

logger.info("Информация о местах с Wikivoyage добавлена в DataFrame df.")
# Out:
# 2025-03-04 17:07:11,821 [INFO] [__main__:2] - Парсинг страниц Wikivoyage ( с помощью selenium).
# 2025-03-04 17:07:11,825 [DEBUG] [__main__:17] - Для Erfurt.
# 2025-03-04 17:07:18,466 [DEBUG] [__main__:47] - Найдено 1 типов мест и 20 мест для Erfurt.
# 2025-03-04 17:07:18,467 [DEBUG] [__main__:17] - Для Glasgow.
# 2025-03-04 17:07:26,998 [DEBUG] [__main__:47] - Найдено 6 типов мест и 84 мест для Glasgow.
# 2025-03-04 17:07:27,000 [DEBUG] [__main__:17] - Для Chambery.
# 2025-03-04 17:07:33,531 [DEBUG] [__main__:47] - Найдено 0 типов мест и 1 мест для Chambery.
# 2025-03-04 17:07:33,533 [DEBUG] [__main__:17] - Для Montreal.
# 2025-03-04 17:07:40,740 [DEBUG] [__main__:47] - Найдено 3 типов мест и 12 мест для Montreal.
# 2025-03-04 17:07:40,741 [DEBUG] [__main__:17] - Для Nelson.
# 2025-03-04 17:07:46,990 [DEBUG] [__main__:47] - Найдено 0 типов мест и 0 мест для Nelson.
# 2025-03-04 17:07:46,991 [DEBUG] [__main__:17] - Для Djerba.
# 2025-03-04 17:07:53,615 [DEBUG] [__main__:47] - Найдено 0 типов мест и 20 мест для Djerba.
# 2025-03-04 17:07:53,619 [DEBUG] [__main__:17] - Для Brisbane.
# 2025-03-04 17:08:02,821 [DEBUG] [__main__:47] - Найдено 4 типов мест и 41 мест для Brisbane.
# 2025-03-04 17:08:02,822 [DEBUG] [__main__:17] - Для Toulon.
# 2025-03-04 17:08:12,479 [DEBUG] [__main__:47] - Найдено 5 типов мест и 3 мест для Toulon.
# 2025-03-04 17:08:12,482 [DEBUG] [__main__:17] - Для Jinan.
# 2025-03-04 17:08:22,046 [DEBUG] [__main__:47] - Найдено 9 типов мест и 12 мест для Jinan.
# 2025-03-04 17:08:22,047 [DEBUG] [__main__:17] - Для Erfurt.
# 2025-03-04 17:08:29,015 [DEBUG] [__main__:47] - Найдено 1 типов мест и 20 мест для Erfurt.
# 2025-03-04 17:08:29,016 [DEBUG] [__main__:17] - Для Bermuda.
# 2025-03-04 17:08:36,116 [DEBUG] [__main__:47] - Найдено 0 типов мест и 7 мест для Bermuda.
# 2025-03-04 17:08:36,118 [DEBUG] [__main__:17] - Для Karachi.
# 2025-03-04 17:08:45,558 [DEBUG] [__main__:47] - Найдено 4 типов мест и 52 мест для Karachi.
# 2025-03-04 17:08:45,562 [DEBUG] [__main__:17] - Для Naypyidaw.
# 2025-03-04 17:08:53,407 [DEBUG] [__main__:47] - Найдено 0 типов мест и 8 мест для Naypyidaw.
# 2025-03-04 17:08:53,408 [DEBUG] [__main__:17] - Для Larnaca.
# 2025-03-04 17:09:01,188 [DEBUG] [__main__:47] - Найдено 0 типов мест и 9 мест для Larnaca.
# 2025-03-04 17:09:01,192 [DEBUG] [__main__:17] - Для Muscat.
# 2025-03-04 17:09:10,881 [DEBUG] [__main__:47] - Найдено 4 типов мест и 33 мест для Muscat.
# 2025-03-04 17:09:10,882 [DEBUG] [__main__:17] - Для Sydney.
# 2025-03-04 17:09:20,114 [DEBUG] [__main__:47] - Найдено 1 типов мест и 14 мест для Sydney.
# 2025-03-04 17:09:20,120 [DEBUG] [__main__:17] - Для Pisa.
# 2025-03-04 17:09:28,949 [DEBUG] [__main__:47] - Найдено 5 типов мест и 38 мест для Pisa.
# 2025-03-04 17:09:28,950 [DEBUG] [__main__:17] - Для Tirana.
# 2025-03-04 17:09:37,707 [DEBUG] [__main__:47] - Найдено 3 типов мест и 55 мест для Tirana.
# 2025-03-04 17:09:37,709 [DEBUG] [__main__:17] - Для Kuala Lumpur.
# 2025-03-04 17:09:50,629 [DEBUG] [__main__:47] - Найдено 2 типов мест и 9 мест для Kuala Lumpur.
# 2025-03-04 17:09:50,635 [DEBUG] [__main__:17] - Для Bodrum.
# 2025-03-04 17:09:59,190 [DEBUG] [__main__:47] - Найдено 1 типов мест и 7 мест для Bodrum.
# 2025-03-04 17:09:59,191 [DEBUG] [__main__:17] - Для Gazipasa.
# 2025-03-04 17:10:05,756 [DEBUG] [__main__:47] - Найдено 0 типов мест и 0 мест для Gazipasa.
# 2025-03-04 17:10:05,757 [DEBUG] [__main__:17] - Для Milan.
# 2025-03-04 17:10:18,190 [DEBUG] [__main__:47] - Найдено 0 типов мест и 2 мест для Milan.
# 2025-03-04 17:10:18,191 [DEBUG] [__main__:17] - Для Venice.
# 2025-03-04 17:10:26,436 [DEBUG] [__main__:47] - Найдено 8 типов мест и 93 мест для Venice.
# 2025-03-04 17:10:26,440 [DEBUG] [__main__:17] - Для Warsaw.
# 2025-03-04 17:10:35,180 [DEBUG] [__main__:47] - Найдено 0 типов мест и 4 мест для Warsaw.
# 2025-03-04 17:10:35,182 [DEBUG] [__main__:17] - Для Termez.
# 2025-03-04 17:10:41,834 [DEBUG] [__main__:47] - Найдено 1 типов мест и 1 мест для Termez.
# 2025-03-04 17:10:41,838 [DEBUG] [__main__:17] - Для Jeddah.
# 2025-03-04 17:10:50,338 [DEBUG] [__main__:47] - Найдено 3 типов мест и 12 мест для Jeddah.
# 2025-03-04 17:10:50,340 [DEBUG] [__main__:17] - Для Las Palmas.
# 2025-03-04 17:10:57,985 [DEBUG] [__main__:47] - Найдено 4 типов мест и 13 мест для Las Palmas.
# 2025-03-04 17:10:57,988 [DEBUG] [__main__:17] - Для Utapao.
# 2025-03-04 17:11:05,055 [DEBUG] [__main__:47] - Найдено 0 типов мест и 0 мест для Utapao.
# 2025-03-04 17:11:05,060 [DEBUG] [__main__:17] - Для Sydney.
# 2025-03-04 17:11:12,762 [DEBUG] [__main__:47] - Найдено 1 типов мест и 14 мест для Sydney.
# 2025-03-04 17:11:12,764 [DEBUG] [__main__:17] - Для Manila.
# 2025-03-04 17:11:21,686 [DEBUG] [__main__:47] - Найдено 8 типов мест и 4 мест для Manila.
# 2025-03-04 17:11:21,688 [DEBUG] [__main__:17] - Для Kurgon-Tyube (Bokhtar).
# 2025-03-04 17:11:28,163 [DEBUG] [__main__:47] - Найдено 0 типов мест и 0 мест для Kurgon-Tyube (Bokhtar).
# 2025-03-04 17:11:28,164 [DEBUG] [__main__:17] - Для Bordeaux.
# 2025-03-04 17:11:36,164 [DEBUG] [__main__:47] - Найдено 3 типов мест и 14 мест для Bordeaux.
# 2025-03-04 17:11:36,166 [DEBUG] [__main__:17] - Для Shanghai.
# 2025-03-04 17:11:44,549 [DEBUG] [__main__:47] - Найдено 4 типов мест и 52 мест для Shanghai.
# 2025-03-04 17:11:44,555 [DEBUG] [__main__:17] - Для Colombo.
# 2025-03-04 17:11:52,767 [DEBUG] [__main__:47] - Найдено 6 типов мест и 38 мест для Colombo.
# 2025-03-04 17:11:52,768 [DEBUG] [__main__:17] - Для Dushanbe.
# 2025-03-04 17:12:01,394 [DEBUG] [__main__:47] - Найдено 4 типов мест и 18 мест для Dushanbe.
# 2025-03-04 17:12:01,398 [DEBUG] [__main__:17] - Для Pavlodar.
# 2025-03-04 17:12:08,537 [DEBUG] [__main__:47] - Найдено 0 типов мест и 1 мест для Pavlodar.
# 2025-03-04 17:12:08,541 [DEBUG] [__main__:17] - Для Rome.
# 2025-03-04 17:12:18,278 [DEBUG] [__main__:47] - Найдено 10 типов мест и 55 мест для Rome.
# 2025-03-04 17:12:18,280 [DEBUG] [__main__:17] - Для Bahrain.
# 2025-03-04 17:12:26,528 [DEBUG] [__main__:47] - Найдено 0 типов мест и 2 мест для Bahrain.
# 2025-03-04 17:12:26,529 [DEBUG] [__main__:17] - Для Tokyo.
# 2025-03-04 17:12:37,032 [DEBUG] [__main__:47] - Найдено 0 типов мест и 25 мест для Tokyo.
# 2025-03-04 17:12:37,034 [DEBUG] [__main__:17] - Для Budapest.
# 2025-03-04 17:12:47,216 [DEBUG] [__main__:47] - Найдено 0 типов мест и 12 мест для Budapest.
# 2025-03-04 17:12:47,218 [DEBUG] [__main__:17] - Для Vienna.
# 2025-03-04 17:12:56,111 [DEBUG] [__main__:47] - Найдено 0 типов мест и 0 мест для Vienna.
# 2025-03-04 17:12:56,112 [DEBUG] [__main__:17] - Для Goa.
# 2025-03-04 17:13:03,106 [DEBUG] [__main__:47] - Найдено 3 типов мест и 27 мест для Goa.
# 2025-03-04 17:13:03,110 [DEBUG] [__main__:17] - Для Mumbai.
# 2025-03-04 17:13:11,942 [DEBUG] [__main__:47] - Найдено 7 типов мест и 3 мест для Mumbai.
# 2025-03-04 17:13:11,944 [DEBUG] [__main__:17] - Для Namangan.
# 2025-03-04 17:13:19,205 [DEBUG] [__main__:47] - Найдено 0 типов мест и 1 мест для Namangan.
# 2025-03-04 17:13:19,212 [DEBUG] [__main__:17] - Для Pavlodar.
# 2025-03-04 17:13:27,447 [DEBUG] [__main__:47] - Найдено 0 типов мест и 1 мест для Pavlodar.
# 2025-03-04 17:13:27,449 [DEBUG] [__main__:17] - Для Baku.
# 2025-03-04 17:13:35,848 [DEBUG] [__main__:47] - Найдено 5 типов мест и 43 мест для Baku.
# 2025-03-04 17:13:35,851 [DEBUG] [__main__:17] - Для Kunming.
# 2025-03-04 17:13:44,190 [DEBUG] [__main__:47] - Найдено 5 типов мест и 37 мест для Kunming.
# 2025-03-04 17:13:44,191 [DEBUG] [__main__:17] - Для Pisa.
# 2025-03-04 17:13:51,142 [DEBUG] [__main__:47] - Найдено 5 типов мест и 38 мест для Pisa.
# 2025-03-04 17:13:51,148 [DEBUG] [__main__:17] - Для Dushanbe.
# 2025-03-04 17:13:58,919 [DEBUG] [__main__:47] - Найдено 4 типов мест и 18 мест для Dushanbe.
# 2025-03-04 17:13:58,920 [DEBUG] [__main__:17] - Для Nevsehir.
# 2025-03-04 17:14:06,186 [DEBUG] [__main__:47] - Найдено 1 типов мест и 9 мест для Nevsehir.
# 2025-03-04 17:14:06,188 [DEBUG] [__main__:17] - Для Khujand.
# 2025-03-04 17:14:13,576 [DEBUG] [__main__:47] - Найдено 0 типов мест и 2 мест для Khujand.
# 2025-03-04 17:14:13,581 [DEBUG] [__main__:17] - Для Nha Trang.
# 2025-03-04 17:14:21,174 [DEBUG] [__main__:47] - Найдено 3 типов мест и 0 мест для Nha Trang.
# 2025-03-04 17:14:21,177 [DEBUG] [__main__:17] - Для Jeddah.
# 2025-03-04 17:14:28,461 [DEBUG] [__main__:47] - Найдено 3 типов мест и 12 мест для Jeddah.
# 2025-03-04 17:14:28,462 [DEBUG] [__main__:17] - Для Dubai.
# 2025-03-04 17:14:36,679 [DEBUG] [__main__:47] - Найдено 0 типов мест и 1 мест для Dubai.
# 2025-03-04 17:14:36,680 [DEBUG] [__main__:17] - Для Budapest.
# 2025-03-04 17:14:45,154 [DEBUG] [__main__:47] - Найдено 0 типов мест и 12 мест для Budapest.
# 2025-03-04 17:14:45,156 [DEBUG] [__main__:17] - Для Gaziantep.
# 2025-03-04 17:14:53,368 [DEBUG] [__main__:47] - Найдено 0 типов мест и 10 мест для Gaziantep.
# 2025-03-04 17:14:53,373 [DEBUG] [__main__:17] - Для Tashkent.
# 2025-03-04 17:15:02,140 [DEBUG] [__main__:47] - Найдено 4 типов мест и 20 мест для Tashkent.
# 2025-03-04 17:15:02,142 [DEBUG] [__main__:17] - Для Antalya.
# 2025-03-04 17:15:09,501 [DEBUG] [__main__:47] - Найдено 1 типов мест и 18 мест для Antalya.
# 2025-03-04 17:15:09,504 [DEBUG] [__main__:17] - Для Hambantota.
# 2025-03-04 17:15:16,603 [DEBUG] [__main__:47] - Найдено 0 типов мест и 0 мест для Hambantota.
# 2025-03-04 17:15:16,604 [DEBUG] [__main__:17] - Для Kuala Lumpur.
# 2025-03-04 17:15:24,468 [DEBUG] [__main__:47] - Найдено 2 типов мест и 9 мест для Kuala Lumpur.
# 2025-03-04 17:15:24,473 [DEBUG] [__main__:17] - Для Bodrum.
# 2025-03-04 17:15:31,473 [DEBUG] [__main__:47] - Найдено 1 типов мест и 7 мест для Bodrum.
# 2025-03-04 17:15:31,474 [DEBUG] [__main__:17] - Для Almaty.
# 2025-03-04 17:15:40,258 [DEBUG] [__main__:47] - Найдено 2 типов мест и 21 мест для Almaty.
# 2025-03-04 17:15:40,259 [DEBUG] [__main__:17] - Для Larnaca.
# 2025-03-04 17:15:46,971 [DEBUG] [__main__:47] - Найдено 0 типов мест и 9 мест для Larnaca.
# 2025-03-04 17:15:46,973 [DEBUG] [__main__:17] - Для Namangan.
# 2025-03-04 17:15:53,500 [DEBUG] [__main__:47] - Найдено 0 типов мест и 1 мест для Namangan.
# 2025-03-04 17:15:53,501 [DEBUG] [__main__:17] - Для Osh.
# 2025-03-04 17:16:01,772 [DEBUG] [__main__:47] - Найдено 1 типов мест и 7 мест для Osh.
# 2025-03-04 17:16:01,773 [DEBUG] [__main__:17] - Для Fergana.
# 2025-03-04 17:16:08,773 [DEBUG] [__main__:47] - Найдено 0 типов мест и 0 мест для Fergana.
# 2025-03-04 17:16:08,775 [DEBUG] [__main__:17] - Для Almaty.
# 2025-03-04 17:16:16,942 [DEBUG] [__main__:47] - Найдено 2 типов мест и 21 мест для Almaty.
# 2025-03-04 17:16:16,944 [DEBUG] [__main__:17] - Для Khujand.
# 2025-03-04 17:16:23,586 [DEBUG] [__main__:47] - Найдено 0 типов мест и 2 мест для Khujand.
# 2025-03-04 17:16:23,590 [DEBUG] [__main__:17] - Для Reykjavik.
# 2025-03-04 17:16:33,254 [DEBUG] [__main__:47] - Найдено 3 типов мест и 46 мест для Reykjavik.
# 2025-03-04 17:16:33,256 [DEBUG] [__main__:17] - Для Dubai.
# 2025-03-04 17:16:40,004 [DEBUG] [__main__:47] - Найдено 0 типов мест и 1 мест для Dubai.
# 2025-03-04 17:16:40,005 [DEBUG] [__main__:17] - Для Venice.
# 2025-03-04 17:16:49,242 [DEBUG] [__main__:47] - Найдено 8 типов мест и 93 мест для Venice.
# 2025-03-04 17:16:49,244 [DEBUG] [__main__:17] - Для Tashkent.
# 2025-03-04 17:16:56,586 [DEBUG] [__main__:47] - Найдено 4 типов мест и 20 мест для Tashkent.
# 2025-03-04 17:16:56,588 [DEBUG] [__main__:17] - Для Lagos.
# 2025-03-04 17:17:04,803 [DEBUG] [__main__:47] - Найдено 0 типов мест и 2 мест для Lagos.
# 2025-03-04 17:17:04,805 [DEBUG] [__main__:17] - Для Shenzhen.
# 2025-03-04 17:17:13,025 [DEBUG] [__main__:47] - Найдено 0 типов мест и 7 мест для Shenzhen.
# 2025-03-04 17:17:13,029 [DEBUG] [__main__:17] - Для Abu Dhabi.
# 2025-03-04 17:17:20,640 [DEBUG] [__main__:47] - Найдено 3 типов мест и 24 мест для Abu Dhabi.
# 2025-03-04 17:17:20,642 [DEBUG] [__main__:17] - Для London.
# 2025-03-04 17:17:31,410 [DEBUG] [__main__:47] - Найдено 6 типов мест и 42 мест для London.
# 2025-03-04 17:17:31,412 [DEBUG] [__main__:17] - Для Hurghada.
# 2025-03-04 17:17:38,635 [DEBUG] [__main__:47] - Найдено 0 типов мест и 0 мест для Hurghada.
# 2025-03-04 17:17:38,636 [DEBUG] [__main__:17] - Для Paris.
# 2025-03-04 17:17:51,107 [DEBUG] [__main__:47] - Найдено 4 типов мест и 32 мест для Paris.
# 2025-03-04 17:17:51,108 [DEBUG] [__main__:17] - Для Yangon.
# 2025-03-04 17:18:00,702 [DEBUG] [__main__:47] - Найдено 4 типов мест и 40 мест для Yangon.
# 2025-03-04 17:18:00,704 [DEBUG] [__main__:17] - Для Belgrade.
# 2025-03-04 17:18:11,746 [DEBUG] [__main__:47] - Найдено 3 типов мест и 55 мест для Belgrade.
# 2025-03-04 17:18:11,747 [DEBUG] [__main__:17] - Для Tashkent.
# 2025-03-04 17:18:20,070 [DEBUG] [__main__:47] - Найдено 4 типов мест и 20 мест для Tashkent.
# 2025-03-04 17:18:20,072 [DEBUG] [__main__:17] - Для Bangkok.
# 2025-03-04 17:18:27,900 [DEBUG] [__main__:47] - Найдено 2 типов мест и 17 мест для Bangkok.
# 2025-03-04 17:18:27,904 [DEBUG] [__main__:17] - Для Utapao.
# 2025-03-04 17:18:34,101 [DEBUG] [__main__:47] - Найдено 0 типов мест и 0 мест для Utapao.
# 2025-03-04 17:18:34,103 [DEBUG] [__main__:17] - Для Krabi.
# 2025-03-04 17:18:40,522 [DEBUG] [__main__:47] - Найдено 0 типов мест и 0 мест для Krabi.
# 2025-03-04 17:18:40,524 [DEBUG] [__main__:17] - Для Tenerife.
# 2025-03-04 17:18:48,956 [DEBUG] [__main__:47] - Найдено 2 типов мест и 57 мест для Tenerife.
# 2025-03-04 17:18:48,959 [DEBUG] [__main__:17] - Для Kulyab.
# 2025-03-04 17:18:55,686 [DEBUG] [__main__:47] - Найдено 0 типов мест и 0 мест для Kulyab.
# 2025-03-04 17:18:55,687 [DEBUG] [__main__:17] - Для Nha Trang.
# 2025-03-04 17:19:02,737 [DEBUG] [__main__:47] - Найдено 3 типов мест и 0 мест для Nha Trang.
# 2025-03-04 17:19:02,742 [DEBUG] [__main__:17] - Для Phuket.
# 2025-03-04 17:19:10,624 [DEBUG] [__main__:47] - Найдено 0 типов мест и 0 мест для Phuket.
# 2025-03-04 17:19:10,628 [DEBUG] [__main__:17] - Для Goa.
# 2025-03-04 17:19:17,691 [DEBUG] [__main__:47] - Найдено 3 типов мест и 27 мест для Goa.
# 2025-03-04 17:19:17,694 [DEBUG] [__main__:17] - Для Montego Bay.
# 2025-03-04 17:19:26,231 [DEBUG] [__main__:47] - Найдено 0 типов мест и 2 мест для Montego Bay.
# 2025-03-04 17:19:26,232 [DEBUG] [__main__:17] - Для Utapao.
# 2025-03-04 17:19:33,456 [DEBUG] [__main__:47] - Найдено 0 типов мест и 0 мест для Utapao.
# 2025-03-04 17:19:33,459 [DEBUG] [__main__:17] - Для Samarkand.
# 2025-03-04 17:19:41,816 [DEBUG] [__main__:47] - Найдено 0 типов мест и 22 мест для Samarkand.
# 2025-03-04 17:19:41,817 [DEBUG] [__main__:17] - Для Guangzhou.
# 2025-03-04 17:19:50,807 [DEBUG] [__main__:47] - Найдено 0 типов мест и 1 мест для Guangzhou.
# 2025-03-04 17:19:50,810 [DEBUG] [__main__:17] - Для Siem Reap.
# 2025-03-04 17:20:03,408 [DEBUG] [__main__:47] - Найдено 3 типов мест и 18 мест для Siem Reap.
# 2025-03-04 17:20:03,410 [DEBUG] [__main__:17] - Для Bangkok.
# 2025-03-04 17:20:13,030 [DEBUG] [__main__:47] - Найдено 2 типов мест и 17 мест для Bangkok.
# 2025-03-04 17:20:13,031 [DEBUG] [__main__:17] - Для Tokyo.
# 2025-03-04 17:20:22,437 [DEBUG] [__main__:47] - Найдено 0 типов мест и 25 мест для Tokyo.
# 2025-03-04 17:20:22,438 [DEBUG] [__main__:17] - Для Tashkent.
# 2025-03-04 17:20:30,782 [DEBUG] [__main__:47] - Найдено 4 типов мест и 20 мест для Tashkent.
# 2025-03-04 17:20:30,785 [DEBUG] [__main__:17] - Для Hanoi.
# 2025-03-04 17:20:41,494 [DEBUG] [__main__:47] - Найдено 8 типов мест и 59 мест для Hanoi.
# 2025-03-04 17:20:41,496 [DEBUG] [__main__:17] - Для Yangon.
# 2025-03-04 17:20:49,310 [DEBUG] [__main__:47] - Найдено 4 типов мест и 40 мест для Yangon.
# 2025-03-04 17:20:49,314 [DEBUG] [__main__:17] - Для London.
# 2025-03-04 17:21:01,374 [DEBUG] [__main__:47] - Найдено 6 типов мест и 42 мест для London.
# 2025-03-04 17:21:01,377 [DEBUG] [__main__:17] - Для Astana.
# 2025-03-04 17:21:09,467 [DEBUG] [__main__:47] - Найдено 6 типов мест и 32 мест для Astana.
# 2025-03-04 17:21:09,469 [DEBUG] [__main__:17] - Для Yerevan.
# 2025-03-04 17:21:17,414 [DEBUG] [__main__:47] - Найдено 5 типов мест и 61 мест для Yerevan.
# 2025-03-04 17:21:17,415 [DEBUG] [__main__:17] - Для Termez.
# 2025-03-04 17:21:24,204 [DEBUG] [__main__:47] - Найдено 1 типов мест и 1 мест для Termez.
# 2025-03-04 17:21:24,209 [DEBUG] [__main__:17] - Для Tbilisi.
# 2025-03-04 17:21:32,703 [DEBUG] [__main__:47] - Найдено 4 типов мест и 71 мест для Tbilisi.
# 2025-03-04 17:21:32,704 [DEBUG] [__main__:17] - Для Belgrade.
# 2025-03-04 17:21:40,995 [DEBUG] [__main__:47] - Найдено 3 типов мест и 55 мест для Belgrade.
# 2025-03-04 17:21:40,997 [DEBUG] [__main__:17] - Для Almaty.
# 2025-03-04 17:21:47,727 [DEBUG] [__main__:47] - Найдено 2 типов мест и 21 мест для Almaty.
# 2025-03-04 17:21:47,728 [DEBUG] [__main__:17] - Для Tashkent.
# 2025-03-04 17:21:55,796 [DEBUG] [__main__:47] - Найдено 4 типов мест и 20 мест для Tashkent.
# 2025-03-04 17:21:55,801 [DEBUG] [__main__:17] - Для Jeddah.
# 2025-03-04 17:22:04,090 [DEBUG] [__main__:47] - Найдено 3 типов мест и 12 мест для Jeddah.
# 2025-03-04 17:22:04,092 [DEBUG] [__main__:17] - Для Anchorage.
# 2025-03-04 17:22:11,464 [DEBUG] [__main__:47] - Найдено 0 типов мест и 14 мест для Anchorage.
# 2025-03-04 17:22:11,467 [DEBUG] [__main__:17] - Для Bangkok.
# 2025-03-04 17:22:20,258 [DEBUG] [__main__:47] - Найдено 2 типов мест и 17 мест для Bangkok.
# 2025-03-04 17:22:20,260 [DEBUG] [__main__:17] - Для Guangzhou.
# 2025-03-04 17:22:27,362 [DEBUG] [__main__:47] - Найдено 0 типов мест и 1 мест для Guangzhou.
# 2025-03-04 17:22:27,366 [DEBUG] [__main__:17] - Для Utapao.
# 2025-03-04 17:22:33,895 [DEBUG] [__main__:47] - Найдено 0 типов мест и 0 мест для Utapao.
# 2025-03-04 17:22:33,900 [DEBUG] [__main__:17] - Для Kunming.
# 2025-03-04 17:22:42,391 [DEBUG] [__main__:47] - Найдено 5 типов мест и 37 мест для Kunming.
# 2025-03-04 17:22:42,395 [DEBUG] [__main__:17] - Для Ho Chi Minh City.
# 2025-03-04 17:22:50,715 [DEBUG] [__main__:47] - Найдено 4 типов мест и 35 мест для Ho Chi Minh City.
# 2025-03-04 17:22:50,717 [DEBUG] [__main__:17] - Для Nha Trang.
# 2025-03-04 17:22:58,020 [DEBUG] [__main__:47] - Найдено 3 типов мест и 0 мест для Nha Trang.
# 2025-03-04 17:22:58,024 [DEBUG] [__main__:17] - Для Beijing.
# 2025-03-04 17:23:07,541 [DEBUG] [__main__:47] - Найдено 6 типов мест и 35 мест для Beijing.
# 2025-03-04 17:23:07,545 [DEBUG] [__main__:17] - Для Denpasar (Bali).
# 2025-03-04 17:23:14,521 [DEBUG] [__main__:47] - Найдено 0 типов мест и 0 мест для Denpasar (Bali).
# 2025-03-04 17:23:14,527 [INFO] [__main__:65] - Информация о местах с Wikivoyage добавлена в DataFrame df.

# %%
# мерджим датасеты  df_flights и df
logger.info("Объединение данных о билетах и данных о направлениях/погоде/местах.")
data = pd.merge(df_flights, df, left_on='destination', right_on='Destination', how='left')
logger.info(f"Собран финальный датасет data размера {data.shape} для исследования")
# Out:
# 2025-03-04 17:28:08,406 [INFO] [__main__:2] - Объединение данных о билетах и данных о направлениях/погоде/местах.
# 2025-03-04 17:28:08,460 [INFO] [__main__:4] - Собран финальный датасет data размера (23743, 24) для исследования

# %%
data
# Out:
#       origin destination   price airline flight_number  \
# 0        MOW         ERF   22553      DP           839
# 1        MOW         ERF   22553      DP           839
# 2        MOW         ERF   28136      DP           839
# 3        MOW         ERF   28136      DP           839
# 4        MOW         ERF   31610      2S           012
# ...      ...         ...     ...     ...           ...
# 23738    VVO         DPS  116719      S7          5204
# 23739    VVO         DPS  120878      S7          5204
# 23740    VVO         DPS  145107      S7          6404
# 23741    VVO         DPS  171216      S7          6404
# 23742    VVO         DPS  175366      S7          6404
#
#                     departure_at  transfers  duration  \
# 0      2025-03-08T08:30:00+03:00          1      1740
# 1      2025-03-08T08:30:00+03:00          1      1740
# 2      2025-03-15T09:30:00+03:00          1      1680
# 3      2025-03-15T09:30:00+03:00          1      1680
# 4      2025-03-16T00:50:00+03:00          1       760
# ...                          ...        ...       ...
# 23738  2025-11-19T08:50:00+10:00          4      3690
# 23739  2026-01-02T08:50:00+10:00          4      3065
# 23740  2026-02-01T07:45:00+10:00          4      3755
# 23741  2025-11-01T07:45:00+10:00          2      3615
# 23742  2025-12-01T07:45:00+10:00          2      3390
#
#                                                     link Airline  ...  \
# 0      /search/MOW0803ERF1?t=DP1741422600174151980000...      DP  ...
# 1      /search/MOW0803ERF1?t=DP1741422600174151980000...      DP  ...
# 2      /search/MOW1503ERF1?t=DP1742031000174212460000...      DP  ...
# 3      /search/MOW1503ERF1?t=DP1742031000174212460000...      DP  ...
# 4      /search/MOW1603ERF1?t=2S1742086200174212460000...      DP  ...
# ...                                                  ...     ...  ...
# 23738  /search/VVO1911DPS1?t=S71763542200176375640000...      HO  ...
# 23739  /search/VVO0201DPS1?t=S71767343800176752050000...      HO  ...
# 23740  /search/VVO0102DPS1?t=MH1769931900177015000000...      HO  ...
# 23741  /search/VVO0111DPS1?t=S71761983100176219280000...      HO  ...
# 23742  /search/VVO0112DPS1?t=S71764575100176477130000...      HO  ...
#
#       Duration Flight Number    Price Origin       Origin Name  \
# 0       1680.0           839  28136.0    MOW            Moscow
# 1       1475.0          6708  25906.0    LED  Saint Petersburg
# 2       1680.0           839  28136.0    MOW            Moscow
# 3       1475.0          6708  25906.0    LED  Saint Petersburg
# 4       1680.0           839  28136.0    MOW            Moscow
# ...        ...           ...      ...    ...               ...
# 23738    830.0          6245  39034.0    VVO       Vladivostok
# 23739    830.0          6245  39034.0    VVO       Vladivostok
# 23740    830.0          6245  39034.0    VVO       Vladivostok
# 23741    830.0          6245  39034.0    VVO       Vladivostok
# 23742    830.0          6245  39034.0    VVO       Vladivostok
#
#                                                   Title  Weather Temperature  \
# 0                    Flight deals from Moscow to Erfurt   Clouds        8.93
# 1          Flight deals from Saint Petersburg to Erfurt   Clouds        8.93
# 2                    Flight deals from Moscow to Erfurt   Clouds        8.93
# 3          Flight deals from Saint Petersburg to Erfurt   Clouds        8.93
# 4                    Flight deals from Moscow to Erfurt   Clouds        8.93
# ...                                                 ...      ...         ...
# 23738  Flight deals from Vladivostok to Denpasar (Bali)   Clouds       27.82
# 23739  Flight deals from Vladivostok to Denpasar (Bali)   Clouds       27.82
# 23740  Flight deals from Vladivostok to Denpasar (Bali)   Clouds       27.82
# 23741  Flight deals from Vladivostok to Denpasar (Bali)   Clouds       27.82
# 23742  Flight deals from Vladivostok to Denpasar (Bali)   Clouds       27.82
#
#              Place Types                                             Places
# 0      [Jewish heritage]  [Erfurt Cathedral, Erfurt Cathedral on Wikiped...
# 1      [Jewish heritage]  [Erfurt Cathedral, Erfurt Cathedral on Wikiped...
# 2      [Jewish heritage]  [Erfurt Cathedral, Erfurt Cathedral on Wikiped...
# 3      [Jewish heritage]  [Erfurt Cathedral, Erfurt Cathedral on Wikiped...
# 4      [Jewish heritage]  [Erfurt Cathedral, Erfurt Cathedral on Wikiped...
# ...                  ...                                                ...
# 23738                 []                                                 []
# 23739                 []                                                 []
# 23740                 []                                                 []
# 23741                 []                                                 []
# 23742                 []                                                 []
#
# [23743 rows x 24 columns]

# %%
data.to_csv("data.csv", index=False, encoding="utf-8")

# %% [markdown]
# Мы собрали датасет и он готов к дальнейшему исследованию на EDA!
